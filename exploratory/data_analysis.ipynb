# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import json
import pydicom
import glob
import os
import random

# %%
train = pd.read_csv('data/train.csv')

# %%
test = pd.read_csv('data/test.csv')

# %%
train.head()
# Out:
#    Unnamed: 0  AccessionNumber  BitsAllocated  BitsStored BodyPartExamined  \
# 0           0              NaN              8           8            CHEST
# 1           1              NaN              8           8            CHEST
# 2           2              NaN              8           8            CHEST
# 3           3              NaN              8           8            CHEST
# 4           4              NaN              8           8            CHEST
#
#    Columns ConversionType  HighBit  InstanceNumber  LossyImageCompression  \
# 0     1024            WSD        7               1                      1
# 1     1024            WSD        7               1                      1
# 2     1024            WSD        7               1                      1
# 3     1024            WSD        7               1                      1
# 4     1024            WSD        7               1                      1
#
#     ...   StudyID                                   StudyInstanceUID  \
# 0   ...       NaN  1.2.276.0.7230010.3.1.2.8323329.28530.15178744...
# 1   ...       NaN  1.2.276.0.7230010.3.1.2.8323329.26024.15178744...
# 2   ...       NaN  1.2.276.0.7230010.3.1.2.8323329.11252.15178743...
# 3   ...       NaN  1.2.276.0.7230010.3.1.2.8323329.2293.151787429...
# 4   ...       NaN  1.2.276.0.7230010.3.1.2.8323329.6379.151787432...
#
#    StudyTime  ViewPosition                         class      x      y  width  \
# 0        0.0            PA  No Lung Opacity / Not Normal    NaN    NaN    NaN
# 1        0.0            PA  No Lung Opacity / Not Normal    NaN    NaN    NaN
# 2        0.0            AP  No Lung Opacity / Not Normal    NaN    NaN    NaN
# 3        0.0            PA                        Normal    NaN    NaN    NaN
# 4        0.0            AP                  Lung Opacity  264.0  152.0  213.0
#
#   height  Target
# 0    NaN       0
# 1    NaN       0
# 2    NaN       0
# 3    NaN       0
# 4  379.0       1
#
# [5 rows x 41 columns]

# %%
test.head()
# Out:
#    Unnamed: 0  AccessionNumber  BitsAllocated  BitsStored BodyPartExamined  \
# 0           0              NaN              8           8            CHEST
# 1           1              NaN              8           8            CHEST
# 2           2              NaN              8           8            CHEST
# 3           3              NaN              8           8            CHEST
# 4           4              NaN              8           8            CHEST
#
#    Columns ConversionType  HighBit  InstanceNumber  LossyImageCompression  \
# 0     1024            WSD        7               1                      1
# 1     1024            WSD        7               1                      1
# 2     1024            WSD        7               1                      1
# 3     1024            WSD        7               1                      1
# 4     1024            WSD        7               1                      1
#
#        ...      SamplesPerPixel SeriesDescription  \
# 0      ...                    1          view: AP
# 1      ...                    1          view: PA
# 2      ...                    1          view: PA
# 3      ...                    1          view: PA
# 4      ...                    1          view: PA
#
#                                    SeriesInstanceUID  SeriesNumber  \
# 0  1.2.276.0.7230010.3.1.3.8323329.2012.151787429...             1
# 1  1.2.276.0.7230010.3.1.3.8323329.21574.15178744...             1
# 2  1.2.276.0.7230010.3.1.3.8323329.30005.15178744...             1
# 3  1.2.276.0.7230010.3.1.3.8323329.29261.15178744...             1
# 4  1.2.276.0.7230010.3.1.3.8323329.8527.151787433...             1
#
#   SpecificCharacterSet StudyDate  StudyID  \
# 0           ISO_IR 100  19010101      NaN
# 1           ISO_IR 100  19010101      NaN
# 2           ISO_IR 100  19010101      NaN
# 3           ISO_IR 100  19010101      NaN
# 4           ISO_IR 100  19010101      NaN
#
#                                     StudyInstanceUID StudyTime  ViewPosition
# 0  1.2.276.0.7230010.3.1.2.8323329.2012.151787429...       0.0            AP
# 1  1.2.276.0.7230010.3.1.2.8323329.21574.15178744...       0.0            PA
# 2  1.2.276.0.7230010.3.1.2.8323329.30005.15178744...       0.0            PA
# 3  1.2.276.0.7230010.3.1.2.8323329.29261.15178744...       0.0            PA
# 4  1.2.276.0.7230010.3.1.2.8323329.8527.151787433...       0.0            PA
#
# [5 rows x 35 columns]

# %%
def summarise_data(df):
    df_summary = df.describe(include = "all").transpose()
    
    #Overwrite the descibe unique count as it ignore integer/float types.
    df_summary['unique'] = df.T.apply(lambda x: x.nunique(), axis=1)
    #Create a missing %
    df_summary['missing'] = 1 - df_summary['count']/len(df)
    
    #get column data type
    df_summary['dtype'] = df.dtypes
    
    #get the column names and reset index
    df_summary['col'] = df_summary.index
    df_summary = df_summary.reset_index(drop = True)

    #Sort the summary table
    df_summary = df_summary.sort_values(by=['dtype', 'unique','col','missing'])
    
    col_order = ['col','dtype','unique','count','missing','top','freq','mean','std','min','25%','50%','75%','max']
#     col_order = ['col','dtype','unique','count','missing','mean','std','min','25%','50%','75%','max']
    
    return(df_summary[col_order])
    #return(df_summary)

# %%
summarise_data(train)
# Out:
#                             col    dtype  unique  count   missing  \
# 2                 BitsAllocated    int64       1  35875         0
# 3                    BitsStored    int64       1  35875         0
# 5                       Columns    int64       1  35875         0
# 7                       HighBit    int64       1  35875         0
# 8                InstanceNumber    int64       1  35875         0
# 9         LossyImageCompression    int64       1  35875         0
# 19          PixelRepresentation    int64       1  35875         0
# 22                         Rows    int64       1  35875         0
# 25              SamplesPerPixel    int64       1  35875         0
# 28                 SeriesNumber    int64       1  35875         0
# 30                    StudyDate    int64       1  35875         0
# 40                       Target    int64       2  35875         0
# 12                   PatientAge    int64      97  35875         0
# 0                    Unnamed: 0    int64   35875  35875         0
# 1               AccessionNumber  float64       0      0         1
# 13             PatientBirthDate  float64       0      0         1
# 16           PatientOrientation  float64       0      0         1
# 21       ReferringPhysicianName  float64       0      0         1
# 31                      StudyID  float64       0      0         1
# 33                    StudyTime  float64       1  35875         0
# 38                        width  float64     346  15850  0.558188
# 39                       height  float64     722  15850  0.558188
# 37                            y  float64     722  15850  0.558188
# 36                            x  float64     738  15850  0.558188
# 4              BodyPartExamined   object       1  35875         0
# 6                ConversionType   object       1  35875         0
# 10  LossyImageCompressionMethod   object       1  35875         0
# 11                     Modality   object       1  35875         0
# 18    PhotometricInterpretation   object       1  35875         0
# 23                  SOPClassUID   object       1  35875         0
# 29         SpecificCharacterSet   object       1  35875         0
# 17                   PatientSex   object       2  35875         0
# 26            SeriesDescription   object       2  35875         0
# 34                 ViewPosition   object       2  35875         0
# 35                        class   object       3  35875         0
# 20                 PixelSpacing   object      18  35875         0
# 15                  PatientName   object   25684  35875         0
# 24               SOPInstanceUID   object   25684  35875         0
# 27            SeriesInstanceUID   object   25684  35875         0
# 32             StudyInstanceUID   object   25684  35875         0
# 14                    patientId   object   25684  35875         0
#
#                                                   top   freq         mean  \
# 2                                                 NaN    NaN            8
# 3                                                 NaN    NaN            8
# 5                                                 NaN    NaN         1024
# 7                                                 NaN    NaN            7
# 8                                                 NaN    NaN            1
# 9                                                 NaN    NaN            1
# 19                                                NaN    NaN            0
# 22                                                NaN    NaN         1024
# 25                                                NaN    NaN            1
# 28                                                NaN    NaN            1
# 30                                                NaN    NaN  1.90101e+07
# 40                                                NaN    NaN     0.441812
# 12                                                NaN    NaN      46.4663
# 0                                                 NaN    NaN        17937
# 1                                                 NaN    NaN          NaN
# 13                                                NaN    NaN          NaN
# 16                                                NaN    NaN          NaN
# 21                                                NaN    NaN          NaN
# 31                                                NaN    NaN          NaN
# 33                                                NaN    NaN            0
# 38                                                NaN    NaN      221.858
# 39                                                NaN    NaN      343.392
# 37                                                NaN    NaN      356.208
# 36                                                NaN    NaN      396.751
# 4                                               CHEST  35875          NaN
# 6                                                 WSD  35875          NaN
# 10                                        ISO_10918_1  35875          NaN
# 11                                                 CR  35875          NaN
# 18                                        MONOCHROME2  35875          NaN
# 23                          1.2.840.10008.5.1.4.1.1.7  35875          NaN
# 29                                         ISO_IR 100  35875          NaN
# 17                                                  M  20443          NaN
# 26                                           view: AP  20714          NaN
# 34                                                 AP  20714          NaN
# 35                                       Lung Opacity  15850          NaN
# 20                                 ['0.168', '0.168']  13883          NaN
# 15               8dc8e54b-5b05-4dac-80b9-fa48878621e2     16          NaN
# 24  1.2.276.0.7230010.3.1.4.8323329.2740.151787429...     16          NaN
# 27  1.2.276.0.7230010.3.1.3.8323329.21152.15178744...     16          NaN
# 32  1.2.276.0.7230010.3.1.2.8323329.2740.151787429...     16          NaN
# 14               8dc8e54b-5b05-4dac-80b9-fa48878621e2     16          NaN
#
#         std          min          25%          50%          75%          max
# 2         0            8            8            8            8            8
# 3         0            8            8            8            8            8
# 5         0         1024         1024         1024         1024         1024
# 7         0            7            7            7            7            7
# 8         0            1            1            1            1            1
# 9         0            1            1            1            1            1
# 19        0            0            0            0            0            0
# 22        0         1024         1024         1024         1024         1024
# 25        0            1            1            1            1            1
# 28        0            1            1            1            1            1
# 30        0  1.90101e+07  1.90101e+07  1.90101e+07  1.90101e+07  1.90101e+07
# 40  0.49661            0            0            0            1            1
# 12  17.0397            1           34           48           59          155
# 0   10356.4            0       8968.5        17937      26905.5        35874
# 1       NaN          NaN          NaN          NaN          NaN          NaN
# 13      NaN          NaN          NaN          NaN          NaN          NaN
# 16      NaN          NaN          NaN          NaN          NaN          NaN
# 21      NaN          NaN          NaN          NaN          NaN          NaN
# 31      NaN          NaN          NaN          NaN          NaN          NaN
# 33        0            0            0            0            0            0
# 38  58.8929           40          181          221          262          528
# 39  159.224           45          214          317          459          942
# 37  148.591            2          239          349          468          881
# 36  204.362            2          207          338          594          817
# 4       NaN          NaN          NaN          NaN          NaN          NaN
# 6       NaN          NaN          NaN          NaN          NaN          NaN
# 10      NaN          NaN          NaN          NaN          NaN          NaN
# 11      NaN          NaN          NaN          NaN          NaN          NaN
# 18      NaN          NaN          NaN          NaN          NaN          NaN
# 23      NaN          NaN          NaN          NaN          NaN          NaN
# 29      NaN          NaN          NaN          NaN          NaN          NaN
# 17      NaN          NaN          NaN          NaN          NaN          NaN
# 26      NaN          NaN          NaN          NaN          NaN          NaN
# 34      NaN          NaN          NaN          NaN          NaN          NaN
# 35      NaN          NaN          NaN          NaN          NaN          NaN
# 20      NaN          NaN          NaN          NaN          NaN          NaN
# 15      NaN          NaN          NaN          NaN          NaN          NaN
# 24      NaN          NaN          NaN          NaN          NaN          NaN
# 27      NaN          NaN          NaN          NaN          NaN          NaN
# 32      NaN          NaN          NaN          NaN          NaN          NaN
# 14      NaN          NaN          NaN          NaN          NaN          NaN

# %%
summarise_data(test)
# Out:
#                             col    dtype  unique count missing  \
# 2                 BitsAllocated    int64       1  1000       0
# 3                    BitsStored    int64       1  1000       0
# 5                       Columns    int64       1  1000       0
# 7                       HighBit    int64       1  1000       0
# 8                InstanceNumber    int64       1  1000       0
# 9         LossyImageCompression    int64       1  1000       0
# 19          PixelRepresentation    int64       1  1000       0
# 22                         Rows    int64       1  1000       0
# 25              SamplesPerPixel    int64       1  1000       0
# 28                 SeriesNumber    int64       1  1000       0
# 30                    StudyDate    int64       1  1000       0
# 12                   PatientAge    int64      79  1000       0
# 0                    Unnamed: 0    int64    1000  1000       0
# 1               AccessionNumber  float64       0     0       1
# 13             PatientBirthDate  float64       0     0       1
# 16           PatientOrientation  float64       0     0       1
# 21       ReferringPhysicianName  float64       0     0       1
# 31                      StudyID  float64       0     0       1
# 33                    StudyTime  float64       1  1000       0
# 4              BodyPartExamined   object       1  1000       0
# 6                ConversionType   object       1  1000       0
# 10  LossyImageCompressionMethod   object       1  1000       0
# 11                     Modality   object       1  1000       0
# 18    PhotometricInterpretation   object       1  1000       0
# 23                  SOPClassUID   object       1  1000       0
# 29         SpecificCharacterSet   object       1  1000       0
# 17                   PatientSex   object       2  1000       0
# 26            SeriesDescription   object       2  1000       0
# 34                 ViewPosition   object       2  1000       0
# 20                 PixelSpacing   object       7  1000       0
# 15                  PatientName   object    1000  1000       0
# 24               SOPInstanceUID   object    1000  1000       0
# 27            SeriesInstanceUID   object    1000  1000       0
# 32             StudyInstanceUID   object    1000  1000       0
# 14                    patientId   object    1000  1000       0
#
#                                                   top  freq         mean  \
# 2                                                 NaN   NaN            8
# 3                                                 NaN   NaN            8
# 5                                                 NaN   NaN         1024
# 7                                                 NaN   NaN            7
# 8                                                 NaN   NaN            1
# 9                                                 NaN   NaN            1
# 19                                                NaN   NaN            0
# 22                                                NaN   NaN         1024
# 25                                                NaN   NaN            1
# 28                                                NaN   NaN            1
# 30                                                NaN   NaN  1.90101e+07
# 12                                                NaN   NaN       47.198
# 0                                                 NaN   NaN        499.5
# 1                                                 NaN   NaN          NaN
# 13                                                NaN   NaN          NaN
# 16                                                NaN   NaN          NaN
# 21                                                NaN   NaN          NaN
# 31                                                NaN   NaN          NaN
# 33                                                NaN   NaN            0
# 4                                               CHEST  1000          NaN
# 6                                                 WSD  1000          NaN
# 10                                        ISO_10918_1  1000          NaN
# 11                                                 CR  1000          NaN
# 18                                        MONOCHROME2  1000          NaN
# 23                          1.2.840.10008.5.1.4.1.1.7  1000          NaN
# 29                                         ISO_IR 100  1000          NaN
# 17                                                  M   573          NaN
# 26                                           view: PA   532          NaN
# 34                                                 PA   532          NaN
# 20                                 ['0.168', '0.168']   334          NaN
# 15               2f6374c9-baec-4236-acb4-a3815dc8243a     1          NaN
# 24  1.2.276.0.7230010.3.1.4.8323329.4885.151787431...     1          NaN
# 27  1.2.276.0.7230010.3.1.3.8323329.30555.15178745...     1          NaN
# 32  1.2.276.0.7230010.3.1.2.8323329.4925.151787431...     1          NaN
# 14               2f6374c9-baec-4236-acb4-a3815dc8243a     1          NaN
#
#         std          min          25%          50%          75%          max
# 2         0            8            8            8            8            8
# 3         0            8            8            8            8            8
# 5         0         1024         1024         1024         1024         1024
# 7         0            7            7            7            7            7
# 8         0            1            1            1            1            1
# 9         0            1            1            1            1            1
# 19        0            0            0            0            0            0
# 22        0         1024         1024         1024         1024         1024
# 25        0            1            1            1            1            1
# 28        0            1            1            1            1            1
# 30        0  1.90101e+07  1.90101e+07  1.90101e+07  1.90101e+07  1.90101e+07
# 12  16.2703            3           34           50           59           91
# 0   288.819            0       249.75        499.5       749.25          999
# 1       NaN          NaN          NaN          NaN          NaN          NaN
# 13      NaN          NaN          NaN          NaN          NaN          NaN
# 16      NaN          NaN          NaN          NaN          NaN          NaN
# 21      NaN          NaN          NaN          NaN          NaN          NaN
# 31      NaN          NaN          NaN          NaN          NaN          NaN
# 33        0            0            0            0            0            0
# 4       NaN          NaN          NaN          NaN          NaN          NaN
# 6       NaN          NaN          NaN          NaN          NaN          NaN
# 10      NaN          NaN          NaN          NaN          NaN          NaN
# 11      NaN          NaN          NaN          NaN          NaN          NaN
# 18      NaN          NaN          NaN          NaN          NaN          NaN
# 23      NaN          NaN          NaN          NaN          NaN          NaN
# 29      NaN          NaN          NaN          NaN          NaN          NaN
# 17      NaN          NaN          NaN          NaN          NaN          NaN
# 26      NaN          NaN          NaN          NaN          NaN          NaN
# 34      NaN          NaN          NaN          NaN          NaN          NaN
# 20      NaN          NaN          NaN          NaN          NaN          NaN
# 15      NaN          NaN          NaN          NaN          NaN          NaN
# 24      NaN          NaN          NaN          NaN          NaN          NaN
# 27      NaN          NaN          NaN          NaN          NaN          NaN
# 32      NaN          NaN          NaN          NaN          NaN          NaN
# 14      NaN          NaN          NaN          NaN          NaN          NaN

# %%
useless_cols = ['BitsAllocated', 'BitsStored', 'Columns', 'HighBit',
                'InstanceNumber', 'LossyImageCompression', 'PixelRepresentation',
                'Rows', 'SamplesPerPixel', 'SeriesNumber', 'StudyDate', 
                'Unnamed: 0', 'AccessionNumber', 'PatientBirthDate', 'PatientOrientation',
                'ReferringPhysicianName', 'StudyID', 'StudyTime', 'BodyPartExamined',
                'ConversionType', 'LossyImageCompressionMethod', 'Modality', 'PhotometricInterpretation',
                'SOPClassUID', 'SpecificCharacterSet', 'PatientName', 'SOPInstanceUID',
                'SeriesInstanceUID', 'StudyInstanceUID', 'SeriesDescription']

# %%
train = train.drop(useless_cols, axis = 1)

# %%
test = test.drop(useless_cols, axis = 1)

# %%
train.head()
# Out:
#    PatientAge                             patientId PatientSex  \
# 0          51  0004cfab-14fd-4e49-80ba-63a80b6bddd6          F
# 1          48  00313ee0-9eaa-42f4-b0ab-c148ed3241cd          F
# 2          19  00322d4d-1c29-4943-afc9-b6754be640eb          M
# 3          28  003d8fa0-6bf1-40ed-b54c-ac657f8495c5          M
# 4          32  00436515-870c-4b36-a041-de91049b9ab4          F
#
#                                      PixelSpacing ViewPosition  \
# 0  ['0.14300000000000002', '0.14300000000000002']           PA
# 1  ['0.19431099999999998', '0.19431099999999998']           PA
# 2                              ['0.168', '0.168']           AP
# 3  ['0.14300000000000002', '0.14300000000000002']           PA
# 4                              ['0.139', '0.139']           AP
#
#                           class      x      y  width  height  Target
# 0  No Lung Opacity / Not Normal    NaN    NaN    NaN     NaN       0
# 1  No Lung Opacity / Not Normal    NaN    NaN    NaN     NaN       0
# 2  No Lung Opacity / Not Normal    NaN    NaN    NaN     NaN       0
# 3                        Normal    NaN    NaN    NaN     NaN       0
# 4                  Lung Opacity  264.0  152.0  213.0   379.0       1

# %%
test.head()
# Out:
#    PatientAge                             patientId PatientSex  \
# 0          47  2cd2f674-1018-4f20-a1ee-cf09928696d8          M
# 1          39  125a4350-c49f-4056-bfc1-d016c68a1159          M
# 2          28  21b97415-1275-4483-9705-af9174fc2b4f          M
# 3          56  2f06b4d6-f9e2-463a-a8f9-f4b9715b61cb          F
# 4           7  219334b4-6696-4b41-90bd-0c56878ccbe6          F
#
#                                      PixelSpacing ViewPosition
# 0                              ['0.139', '0.139']           AP
# 1                              ['0.168', '0.168']           PA
# 2  ['0.14300000000000002', '0.14300000000000002']           PA
# 3  ['0.14300000000000002', '0.14300000000000002']           PA
# 4                              ['0.139', '0.139']           PA

# %%
train.PatientAge.value_counts()
# Out:
# 58     1184
# 56     1055
# 52      962
# 40      861
# 55      842
# 54      831
# 46      824
# 59      824
# 57      798
# 53      792
# 49      785
# 45      733
# 51      725
# 43      718
# 61      704
# 60      662
# 48      661
# 44      652
# 47      650
# 50      650
# 34      635
# 67      621
# 62      607
# 63      605
# 66      590
# 33      588
# 64      588
# 65      584
# 32      584
# 31      578
#        ...
# 10      132
# 6       117
# 11      117
# 81      108
# 78      106
# 79       90
# 80       67
# 8        60
# 7        50
# 82       46
# 83       39
# 86       35
# 3        33
# 5        30
# 87       30
# 90       29
# 2        29
# 4        19
# 84       19
# 88       18
# 85       17
# 89       10
# 1         5
# 91        4
# 92        2
# 151       1
# 153       1
# 148       1
# 150       1
# 155       1
# Name: PatientAge, Length: 97, dtype: int64

# %%
test.PatientAge.value_counts()
# Out:
# 58    43
# 55    34
# 56    31
# 49    31
# 63    29
# 54    27
# 53    26
# 51    26
# 57    25
# 59    25
# 66    25
# 52    23
# 50    23
# 47    22
# 64    22
# 33    22
# 48    21
# 43    18
# 65    18
# 60    18
# 32    18
# 39    17
# 70    16
# 46    16
# 45    16
# 30    16
# 40    15
# 28    15
# 29    14
# 44    14
#       ..
# 20     9
# 31     9
# 16     8
# 21     8
# 71     7
# 15     7
# 72     7
# 13     6
# 17     5
# 75     5
# 73     5
# 76     4
# 37     4
# 9      4
# 7      3
# 80     3
# 12     2
# 3      2
# 74     2
# 77     2
# 81     2
# 82     2
# 85     1
# 14     1
# 78     1
# 10     1
# 8      1
# 5      1
# 4      1
# 91     1
# Name: PatientAge, Length: 79, dtype: int64

# %%
train.corr()['Target']
# Out:
# PatientAge   -0.064771
# x                  NaN
# y                  NaN
# width              NaN
# height             NaN
# Target        1.000000
# Name: Target, dtype: float64

# %%
train_pneu_only = train[(train['class'] == 'Normal') | (train['class'] == 'Lung Opacity')]

# %%
train_pneu_only.head()
# Out:
#    PatientAge                             patientId PatientSex  \
# 3          28  003d8fa0-6bf1-40ed-b54c-ac657f8495c5          M
# 4          32  00436515-870c-4b36-a041-de91049b9ab4          F
# 5          32  00436515-870c-4b36-a041-de91049b9ab4          F
# 6          32  00436515-870c-4b36-a041-de91049b9ab4          F
# 7          32  00436515-870c-4b36-a041-de91049b9ab4          F
#
#                                      PixelSpacing ViewPosition         class  \
# 3  ['0.14300000000000002', '0.14300000000000002']           PA        Normal
# 4                              ['0.139', '0.139']           AP  Lung Opacity
# 5                              ['0.139', '0.139']           AP  Lung Opacity
# 6                              ['0.139', '0.139']           AP  Lung Opacity
# 7                              ['0.139', '0.139']           AP  Lung Opacity
#
#        x      y  width  height  Target
# 3    NaN    NaN    NaN     NaN       0
# 4  264.0  152.0  213.0   379.0       1
# 5  562.0  152.0  256.0   453.0       1
# 6  264.0  152.0  213.0   379.0       1
# 7  562.0  152.0  256.0   453.0       1

# %%
summarise_data(train_pneu_only)
# Out:
#              col    dtype  unique  count   missing  \
# 10        Target    int64       2  24375         0
# 0     PatientAge    int64      95  24375         0
# 8          width  float64     346  15850  0.349744
# 9         height  float64     722  15850  0.349744
# 7              y  float64     722  15850  0.349744
# 6              x  float64     738  15850  0.349744
# 2     PatientSex   object       2  24375         0
# 4   ViewPosition   object       2  24375         0
# 5          class   object       2  24375         0
# 3   PixelSpacing   object      14  24375         0
# 1      patientId   object   14184  24375         0
#
#                                      top   freq      mean       std  min  25%  \
# 10                                   NaN    NaN  0.650256  0.476899    0    0
# 0                                    NaN    NaN    45.111    17.112    1   32
# 8                                    NaN    NaN   221.858   58.8929   40  181
# 9                                    NaN    NaN   343.392   159.224   45  214
# 7                                    NaN    NaN   356.208   148.591    2  239
# 6                                    NaN    NaN   396.751   204.362    2  207
# 2                                      M  13915       NaN       NaN  NaN  NaN
# 4                                     AP  14975       NaN       NaN  NaN  NaN
# 5                           Lung Opacity  15850       NaN       NaN  NaN  NaN
# 3                     ['0.168', '0.168']   9954       NaN       NaN  NaN  NaN
# 1   0ab261f9-4eb5-42ab-a9a5-e918904d6356     16       NaN       NaN  NaN  NaN
#
#     50%  75%  max
# 10    1    1    1
# 0    46   58  155
# 8   221  262  528
# 9   317  459  942
# 7   349  468  881
# 6   338  594  817
# 2   NaN  NaN  NaN
# 4   NaN  NaN  NaN
# 5   NaN  NaN  NaN
# 3   NaN  NaN  NaN
# 1   NaN  NaN  NaN

# %%
train_pneu_only = train_pneu_only.drop('class', axis = 1)

# %%
train_no_pneu = train[(train['class'] == 'Normal') | (train['class'] == 'No Lung Opacity / Not Normal')]

# %%
train_no_pneu.head()
# Out:
#    PatientAge                             patientId PatientSex  \
# 0          51  0004cfab-14fd-4e49-80ba-63a80b6bddd6          F
# 1          48  00313ee0-9eaa-42f4-b0ab-c148ed3241cd          F
# 2          19  00322d4d-1c29-4943-afc9-b6754be640eb          M
# 3          28  003d8fa0-6bf1-40ed-b54c-ac657f8495c5          M
# 8          54  00569f44-917d-4c86-a842-81832af98c30          M
#
#                                      PixelSpacing ViewPosition  \
# 0  ['0.14300000000000002', '0.14300000000000002']           PA
# 1  ['0.19431099999999998', '0.19431099999999998']           PA
# 2                              ['0.168', '0.168']           AP
# 3  ['0.14300000000000002', '0.14300000000000002']           PA
# 8                              ['0.139', '0.139']           AP
#
#                           class   x   y  width  height  Target
# 0  No Lung Opacity / Not Normal NaN NaN    NaN     NaN       0
# 1  No Lung Opacity / Not Normal NaN NaN    NaN     NaN       0
# 2  No Lung Opacity / Not Normal NaN NaN    NaN     NaN       0
# 3                        Normal NaN NaN    NaN     NaN       0
# 8  No Lung Opacity / Not Normal NaN NaN    NaN     NaN       0

# %%
summarise_data(train_no_pneu)
# Out:
#              col    dtype  unique  count missing  \
# 10        Target    int64       1  20025       0
# 0     PatientAge    int64      96  20025       0
# 9         height  float64       0      0       1
# 8          width  float64       0      0       1
# 6              x  float64       0      0       1
# 7              y  float64       0      0       1
# 2     PatientSex   object       2  20025       0
# 4   ViewPosition   object       2  20025       0
# 5          class   object       2  20025       0
# 3   PixelSpacing   object      18  20025       0
# 1      patientId   object   20025  20025       0
#
#                                                top   freq     mean      std  \
# 10                                             NaN    NaN        0        0
# 0                                              NaN    NaN  47.4482  16.6132
# 9                                              NaN    NaN      NaN      NaN
# 8                                              NaN    NaN      NaN      NaN
# 6                                              NaN    NaN      NaN      NaN
# 7                                              NaN    NaN      NaN      NaN
# 2                                                M  11303      NaN      NaN
# 4                                               PA  12715      NaN      NaN
# 5                     No Lung Opacity / Not Normal  11500      NaN      NaN
# 3   ['0.14300000000000002', '0.14300000000000002']   7963      NaN      NaN
# 1             9f370a9a-98ea-465f-b225-a7b47211fb4c      1      NaN      NaN
#
#     min  25%  50%  75%  max
# 10    0    0    0    0    0
# 0     1   35   50   60  155
# 9   NaN  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN  NaN
# 2   NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN  NaN
# 3   NaN  NaN  NaN  NaN  NaN
# 1   NaN  NaN  NaN  NaN  NaN

# %%
train_no_pneu['class'], uniques = pd.factorize(train_no_pneu['class'])
# Out:
# /anaconda3/envs/pneu/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
train_no_pneu = train_no_pneu.drop('Target', axis = 1)

# %%
train_no_pneu = train_no_pneu.rename(columns = {'class':'Target'})

# %%
train_no_pneu.head()
# Out:
#    PatientAge                             patientId PatientSex  \
# 0          51  0004cfab-14fd-4e49-80ba-63a80b6bddd6          F
# 1          48  00313ee0-9eaa-42f4-b0ab-c148ed3241cd          F
# 2          19  00322d4d-1c29-4943-afc9-b6754be640eb          M
# 3          28  003d8fa0-6bf1-40ed-b54c-ac657f8495c5          M
# 8          54  00569f44-917d-4c86-a842-81832af98c30          M
#
#                                      PixelSpacing ViewPosition  Target   x  \
# 0  ['0.14300000000000002', '0.14300000000000002']           PA       0 NaN
# 1  ['0.19431099999999998', '0.19431099999999998']           PA       0 NaN
# 2                              ['0.168', '0.168']           AP       0 NaN
# 3  ['0.14300000000000002', '0.14300000000000002']           PA       1 NaN
# 8                              ['0.139', '0.139']           AP       0 NaN
#
#     y  width  height
# 0 NaN    NaN     NaN
# 1 NaN    NaN     NaN
# 2 NaN    NaN     NaN
# 3 NaN    NaN     NaN
# 8 NaN    NaN     NaN

# %%
train_no_pneu = train_no_pneu.drop(['x', 'y', 'width', 'height'], axis = 1)

# %%
train = train.drop('PixelSpacing', axis = 1)
test = test.drop('PixelSpacing', axis = 1)
train_pneu_only = train_pneu_only.drop('PixelSpacing', axis = 1)
train_no_pneu = train_no_pneu.drop('PixelSpacing', axis = 1)

# %%
train.head()
# Out:
#    PatientAge                             patientId PatientSex ViewPosition  \
# 0          51  0004cfab-14fd-4e49-80ba-63a80b6bddd6          F           PA
# 1          48  00313ee0-9eaa-42f4-b0ab-c148ed3241cd          F           PA
# 2          19  00322d4d-1c29-4943-afc9-b6754be640eb          M           AP
# 3          28  003d8fa0-6bf1-40ed-b54c-ac657f8495c5          M           PA
# 4          32  00436515-870c-4b36-a041-de91049b9ab4          F           AP
#
#                           class      x      y  width  height  Target
# 0  No Lung Opacity / Not Normal    NaN    NaN    NaN     NaN       0
# 1  No Lung Opacity / Not Normal    NaN    NaN    NaN     NaN       0
# 2  No Lung Opacity / Not Normal    NaN    NaN    NaN     NaN       0
# 3                        Normal    NaN    NaN    NaN     NaN       0
# 4                  Lung Opacity  264.0  152.0  213.0   379.0       1

# %%
test.head()
# Out:
#    PatientAge                             patientId PatientSex ViewPosition
# 0          47  2cd2f674-1018-4f20-a1ee-cf09928696d8          M           AP
# 1          39  125a4350-c49f-4056-bfc1-d016c68a1159          M           PA
# 2          28  21b97415-1275-4483-9705-af9174fc2b4f          M           PA
# 3          56  2f06b4d6-f9e2-463a-a8f9-f4b9715b61cb          F           PA
# 4           7  219334b4-6696-4b41-90bd-0c56878ccbe6          F           PA

# %%
train_pneu_only[train_pneu_only['patientId'] == 'b6862fc0-31f9-4091-b8b1-256192168a0f']
# Out:
#        PatientAge                             patientId PatientSex  \
# 24803          66  b6862fc0-31f9-4091-b8b1-256192168a0f          M
# 24804          66  b6862fc0-31f9-4091-b8b1-256192168a0f          M
# 24805          66  b6862fc0-31f9-4091-b8b1-256192168a0f          M
# 24806          66  b6862fc0-31f9-4091-b8b1-256192168a0f          M
#
#       ViewPosition      x      y  width  height  Target
# 24803           AP  182.0  192.0  293.0   565.0       1
# 24804           AP  627.0  253.0  209.0   523.0       1
# 24805           AP  182.0  192.0  293.0   565.0       1
# 24806           AP  627.0  253.0  209.0   523.0       1

# %%
train_pneu_only.shape
# Out:
# (24375, 9)

# %%
train_no_pneu.head()
# Out:
#    PatientAge                             patientId PatientSex ViewPosition  \
# 0          51  0004cfab-14fd-4e49-80ba-63a80b6bddd6          F           PA
# 1          48  00313ee0-9eaa-42f4-b0ab-c148ed3241cd          F           PA
# 2          19  00322d4d-1c29-4943-afc9-b6754be640eb          M           AP
# 3          28  003d8fa0-6bf1-40ed-b54c-ac657f8495c5          M           PA
# 8          54  00569f44-917d-4c86-a842-81832af98c30          M           AP
#
#    Target
# 0       0
# 1       0
# 2       0
# 3       1
# 8       0

# %%
train_pneu_only.to_csv('train_pneu_only.csv')

# %%
train_no_pneu.to_csv('train_no_pneu.csv')

# %%
train_pneu_not_normal = train[(train['class'] == 'Lung Opacity') | (train['class'] == 'No Lung Opacity / Not Normal')]

# %%
train_pneu_not_normal.head()
# Out:
#    PatientAge                             patientId PatientSex ViewPosition  \
# 0          51  0004cfab-14fd-4e49-80ba-63a80b6bddd6          F           PA
# 1          48  00313ee0-9eaa-42f4-b0ab-c148ed3241cd          F           PA
# 2          19  00322d4d-1c29-4943-afc9-b6754be640eb          M           AP
# 4          32  00436515-870c-4b36-a041-de91049b9ab4          F           AP
# 5          32  00436515-870c-4b36-a041-de91049b9ab4          F           AP
#
#                           class      x      y  width  height  Target
# 0  No Lung Opacity / Not Normal    NaN    NaN    NaN     NaN       0
# 1  No Lung Opacity / Not Normal    NaN    NaN    NaN     NaN       0
# 2  No Lung Opacity / Not Normal    NaN    NaN    NaN     NaN       0
# 4                  Lung Opacity  264.0  152.0  213.0   379.0       1
# 5                  Lung Opacity  562.0  152.0  256.0   453.0       1

# %%
train_pneu_not_normal = train_pneu_not_normal.drop('class', axis = 1)

# %%
train_pneu_not_normal.to_csv('train_pneu_not_normal.csv')

# %%
train_pneu_not_normal.head()
# Out:
#    PatientAge                             patientId PatientSex ViewPosition  \
# 0          51  0004cfab-14fd-4e49-80ba-63a80b6bddd6          F           PA
# 1          48  00313ee0-9eaa-42f4-b0ab-c148ed3241cd          F           PA
# 2          19  00322d4d-1c29-4943-afc9-b6754be640eb          M           AP
# 4          32  00436515-870c-4b36-a041-de91049b9ab4          F           AP
# 5          32  00436515-870c-4b36-a041-de91049b9ab4          F           AP
#
#        x      y  width  height  Target
# 0    NaN    NaN    NaN     NaN       0
# 1    NaN    NaN    NaN     NaN       0
# 2    NaN    NaN    NaN     NaN       0
# 4  264.0  152.0  213.0   379.0       1
# 5  562.0  152.0  256.0   453.0       1
